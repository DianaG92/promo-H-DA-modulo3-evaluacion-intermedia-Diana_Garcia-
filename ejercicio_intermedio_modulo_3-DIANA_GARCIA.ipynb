# %% [markdown]
# #### EVALUACIÓN INTERMEDIA MÓDULO 3

# %% [markdown]
# ##### Los ejercicios planteados son:

# %% [markdown]
# 1. Importa Pandas.

# %%
import pandas as pd

# %% [markdown]
# 2. Exploración del conjunto de datos:

# %% [markdown]
# Carga el fichero, al cargarlo te aparecerá una columna llamada "Unnamed: 0". Carga el dataset sin que aparezca esta columna. Además realiza un análisis exploratorio que incluya:

# %%
data_youtube = pd.read_csv("Spotify_Youtube.csv", index_col=0)
data_youtube
# Out:
#             Artist                                        Url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %% [markdown]
# - Cuando leas el fichero, veras que no podemos ver todas las columnas, utiliza el comando correcto para poder visualizarlas todas cuando hacemos un head.

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# - Primeras 5 filas del dataframe.

# %%
data_youtube.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %% [markdown]
# - Últimas 5 filas del dataframe.

# %%
data_youtube.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri Danceability Energy  \
# ...

# %% [markdown]
# - 10 filas aleatorias del dataframe.

# %%
data_youtube.sample(10)
# Out:
#                       Artist  \
# 4066               Mobb Deep
# 9732                    PNAU
# 5696             Craig David
# 918    Johann Sebastian Bach
# 15454                TV Girl
# 5523             Barry White
# 13482     Tyler, The Creator
# 290                   Tiësto
# 1115            Phil Collins
# 13418        Sherlock Holmes
#
#                                              Url_spotify  \
# 4066   https://open.spotify.com/artist/6O2zJ0tId7g07y...
# 9732   https://open.spotify.com/artist/6n28c9qs9hNGri...
# 5696   https://open.spotify.com/artist/2JyWXPbkqI5ZJa...
# 918    https://open.spotify.com/artist/5aIqB5nVVvmFsv...
# 15454  https://open.spotify.com/artist/0Y6dVaC9DZtPNH...
# 5523   https://open.spotify.com/artist/3rfgbfpPSfXY40...
# 13482  https://open.spotify.com/artist/4V8LLVI7PbaPR0...
# 290    https://open.spotify.com/artist/2o5jDhtHVPhrJd...
# 1115   https://open.spotify.com/artist/4lxfqrEsLX6N1N...
# 13418  https://open.spotify.com/artist/2YlvvdXUqRjiXm...
#
# ...

# %% [markdown]
# - ¿Cuántas filas y columnas tenemos en el dataframe?

# %%
data_youtube.shape
# Out:
# (20718, 27)

# %%
# Procedemos de la siguiente manera para saber el número de filas y columnas por separado (opcional)
print(f"El número de filas es {data_youtube.shape[0]}")
print(f"El número de columnas es {data_youtube.shape[1]}")
# Out:
# El número de filas es 20718
# El número de columnas es 27

# %% [markdown]
# - ¿Cuáles son los tipos de los datos de cada columna del dataframe?

# %%
data_youtube.dtypes
# Out:
# Artist               object
# Url_spotify          object
# Track                object
# Album                object
# Album_type           object
# Uri                  object
# Danceability         object
# Energy               object
# Key                  object
# Loudness             object
# Speechiness          object
# Acousticness         object
# Instrumentalness     object
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Url_youtube          object
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Description          object
# Licensed             object
# Official_video       object
# Stream              float64
# dtype: object

# %% [markdown]
# - ¿Cuántos valores nulos tenemos por columna?

# %%
data_youtube.isnull().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# Official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# - ¿Tenemos filas duplicadas en el dataframe?

# %%
data_youtube.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - Muestra los principales estadísticos para las columnas numéricas del dataframe.

# %%
data_youtube.describe().T
# Out:
#                count          mean           std         min           25%  \
# Liveness     20716.0  1.935210e-01  1.685309e-01      0.0145  9.410000e-02
# Valence      20716.0  5.298533e-01  2.454408e-01      0.0000  3.390000e-01
# Tempo        20716.0  1.206383e+02  2.957902e+01      0.0000  9.700200e+01
# Duration_ms  20716.0  2.247176e+05  1.247905e+05  30985.0000  1.800095e+05
# Views        20248.0  9.393782e+07  2.746443e+08      0.0000  1.826002e+06
# Likes        20177.0  6.633411e+05  1.789324e+06      0.0000  2.158100e+04
# Comments     20149.0  2.751899e+04  1.932347e+05      0.0000  5.090000e+02
# Stream       20142.0  1.359422e+08  2.441321e+08   6574.0000  1.767486e+07
#
#                       50%           75%           max
# Liveness     1.250000e-01  2.370000e-01  1.000000e+00
# Valence      5.370000e-01  7.262500e-01  9.930000e-01
# Tempo        1.199650e+02  1.399350e+02  2.433720e+02
# Duration_ms  2.132845e+05  2.524430e+05  4.676058e+06
# ...

# %% [markdown]
# - Muestra los principales estadísticos para las columnas categóricas del dataframe.

# %%
data_youtube.describe(include="O").T
# Out:
#                   count unique  \
# Artist            20718   2079
# Url_spotify       20718   2079
# Track             20718  17841
# Album             20718  11937
# Album_type        20718      3
# Uri               20718  18862
# Danceability      20716    898
# Energy            20716   1268
# Key               20716     12
# Loudness          20716   9417
# Speechiness       20716   1303
# Acousticness      20716   3138
# Instrumentalness  20716   4012
# Url_youtube       20248  18154
# Title             20248  18146
# Channel           20248   6714
# Description       19842  17395
# Licensed          20248      2
# Official_video    20248      2
#
#                                                                 top   freq
# Artist                                                     Gorillaz     10
# Url_spotify       https://open.spotify.com/artist/3AA28KZvwAUcZu...     10
# Track                     El Ultimo Adiós - Varios Artistas Version     24
# ...

# %% [markdown]
# 3. Preparación de los datos:
#
# - Los nombres de las columnas empiezan con mayúsculas, pon todos los nombres de las columnas en minúsculas.

# %%
data_youtube.columns = data_youtube.columns.str.lower()
data_youtube.columns
# Out:
# Index(['artist', 'url_spotify', 'track', 'album', 'album_type', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'url_youtube', 'title', 'channel', 'views', 'likes',
#        'comments', 'description', 'licensed', 'official_video', 'stream'],
#       dtype='object')

# %% [markdown]
# - Haciendo el análisis exploratorio te deberías haber dado cuenta de que algunas de las variables (danceability, energy, key, loudness, speechiness, acousticness, instrumentalness) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Crea una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.

# %%
columnas_convertidas = ["danceability", "energy", "key", "loudness", "speechiness", "acousticness", "instrumentalness"]

for i in columnas_convertidas:
    data_youtube[i] = data_youtube[i].str.replace(",", ".")

# %% [markdown]
# - Después de haber hecho los cambios, chequea los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, crea otra función o modifica la anterior para que sean de tipo float.

# %%
data_youtube[columnas_convertidas] = data_youtube[columnas_convertidas].astype(float)

# %%
data_youtube.head(2)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              track          album album_type  \
# 0   Feel Good Inc.     Demon Days      album
# 1  Rhinestone Eyes  Plastic Beach      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770       0.00836          0.002330    0.6130    0.772  138.559
# 1       0.0302       0.08690          0.000687    0.0463    0.852   92.761
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# ...

# %% [markdown]
# - Hay algunas canciones cuyo título está en mayúsulas. Crea una función para que todos los títulos estén en minúscula. Haz lo mismo para las columnas de "title" y "album".

# %%
columnas_convertidas = ["track", "title", "album"]

def cambiar_minusculas(columnas_convertidas):
    for columna in columnas:
        data_youtube[columna] = data_youtube[columna].str.lower()
    return columnas_convertidas

# %% [markdown]
# - Algunos de los artistas tienen símbolos raros, en concreto el símbolo $. Crea una función que los reemplaze pos "s".

# %%
# Antes de realizar el ejercicio, debemos averiguar cuántos símbolos $ hay dentro de la columna "artist"
contiene_dollar = data_youtube["artist"].str.contains(r'\$', regex=True).sum()
print(contiene_dollar)
# Out:
# 90

# %%
data_youtube["artist"] = data_youtube["artist"].str.replace("$", "s")
# Out:
# /tmp/ipykernel_662/825014090.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_youtube["artist"] = data_youtube["artist"].str.replace("$", "s")

# %% [markdown]
# 4. Filtrado de datos:
#
# - ¿Cuáles son los valores únicos de la columna "album_type"? Crea tres dataframes diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
print(f"Los valores únicos de album_type son: {data_youtube['album_type'].unique()}")
# Out:
# Los valores únicos de album_type son: ['album' 'single' 'compilation']

# %%
dataframe_tipo = {}
for i in album_types:
    dataframe_tipo[i] = data_youtube[data_youtube["album_type"] == i].copy()
    
canciones_tipo = {i: data_youtube.shape[0] for i, data_youtube in dataframe_tipo.items()}
print("Número de canciones por tipo de album_type:")
for i, num_canciones in canciones_tipo.items():
    print(f"{i}: {num_canciones} canciones")
# Out:
# Número de canciones por tipo de album_type:
# album: 14926 canciones
# single: 5004 canciones
# compilation: 788 canciones

# %%
data_album = data_youtube[data_youtube["album_type"] == "album"]
data_album.sample(2)
# Out:
#                artist                                        url_spotify  \
# 4428         R. Kelly  https://open.spotify.com/artist/2mxe0TnaNL039y...
# 19434  D-Block Europe  https://open.spotify.com/artist/5VadK1havLhK1O...
#
#                                     track          album album_type  \
# 4428   Burn It Up (feat. Wysin & Yandell)  Tp.3 Reloaded      album
# 19434                              Desire   Home Alone 2      album
#
#                                         uri  danceability  energy   key  \
# 4428   spotify:track:6ONZZmVuEVAAHvj0OWuVU1         0.784   0.793  10.0
# 19434  spotify:track:6N0dFsh16LrXwQQJY553en         0.686   0.523   0.0
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 4428     -4.573        0.123         0.112               0.0     0.134
# 19434    -9.454        0.320         0.309               0.0     0.163
#
#        valence   tempo  duration_ms  \
# 4428     0.638  95.977     231773.0
# ...

# %%
data_single = data_youtube[data_youtube["album_type"] == "single"]
data.sample(2)
# Out:
#                 artist                                        url_spotify  \
# 4600  Sir Simon Rattle  https://open.spotify.com/artist/4GQwgdcDQwqtcH...
# 6170    REO Speedwagon  https://open.spotify.com/artist/55vs7NT1KxcFjb...
#
#                                                   track  \
# 4600  tchaikovsky: the nutcracker, op. 71, act i, sc...
# 6170                               ridin' the storm out
#
#                             album album_type  \
# 4600  tchaikovsky: the nutcracker      album
# 6170         ridin' the storm out      album
#
#                                        uri  danceability  energy  key  \
# 4600  spotify:track:6yTPBtEggdlBgGEUL94sn1         0.256   0.246  0.0
# 6170  spotify:track:0SkmxNE5ydxiEN0hzJbMac         0.557   0.798  9.0
#
#       loudness  speechiness  acousticness  instrumentalness  liveness  \
# 4600   -21.403       0.0490        0.9010          0.297000     0.578
# 6170    -5.843       0.0277        0.0158          0.000025     0.547
#
# ...

# %%
data_compilation = data_youtube[data_youtube["album_type"] == "compilation"]
data_compilation.sample(2)
# Out:
#                    artist                                        url_spotify  \
# 3541              The Who  https://open.spotify.com/artist/67ea9eGLXYMsO2...
# 3894  Herbert von Karajan  https://open.spotify.com/artist/5zCaQxjl110XTr...
#
#                                           track                         album  \
# 3541                          The Seeker - Edit  Meaty, Beaty, Big And Bouncy
# 3894  Suite No. 3 in D Major, BWV 1068: II. Air       Born in the 1600s: Bach
#
#        album_type                                   uri  danceability  energy  \
# 3541  compilation  spotify:track:5orygsZ5Ga0jEOvftsXqw2        0.3180  0.6570
# 3894  compilation  spotify:track:0DqFXzLtKkj9JO421NJpl1        0.0769  0.0846
#
#       key  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 3541  2.0   -11.829       0.0358         0.101          0.000003     0.144
# 3894  2.0   -25.997       0.0450         0.922          0.929000     0.113
#
# ...

# %% [markdown]
# - Usando el dataframe de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Muestra los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordena los resultados de mayor a menor en base a la media.

# %%
data_album.groupby("artist")[["danceability", "acousticness", "speechiness"]].agg({
    "danceability": ["mean", "std"],
    "acousticness": ["mean", "std"],
    "speechiness": ["mean", "std"]
}).sort_values(by=("danceability", "mean"), ascending=False).reset_index()
# Out:
#                       artist danceability           acousticness            \
#                                      mean       std         mean       std
# 0                      Latto     0.922333  0.014503     0.027103  0.020747
# 1                      Murda     0.911500  0.030406     0.047350  0.031183
# 2                      Jon Z     0.886000  0.015556     0.227500  0.123744
# 3                   Blueface     0.885000  0.043782     0.134175  0.061273
# 4                  Jung Kook     0.881000       NaN     0.619000       NaN
# ...                      ...          ...       ...          ...       ...
# 1984        Stephen Cleobury     0.142067  0.042212     0.967000  0.020087
# 1985            Ocean Sounds     0.137980  0.063706     0.487978  0.341906
# 1986   Ocean Waves For Sleep     0.133533  0.061768     0.409676  0.344737
# 1987  White Noise for Babies     0.090262  0.163895     0.778625  0.272866
# ...

# %%
data_single.groupby("artist")[["danceability", "acousticness", "speechiness"]].agg({
    "danceability": ["mean", "std"],
    "acousticness": ["mean", "std"],
    "speechiness": ["mean", "std"]
}).sort_values(by=("danceability", "mean"), ascending=False).reset_index()
# Out:
#                       artist danceability           acousticness            \
#                                      mean       std         mean       std
# 0                   The Game       0.9340       NaN       0.0476       NaN
# 1                    El Alfa       0.9250       NaN       0.3550       NaN
# 2                  Peter Fox       0.9110  0.011314       0.4325  0.115258
# 3                     N.W.A.       0.9050       NaN       0.0380       NaN
# 4                      Kelis       0.9030       NaN       0.0498       NaN
# ...                      ...          ...       ...          ...       ...
# 1350          Franz Schubert       0.1630       NaN       0.9800       NaN
# 1351             Daniel Hope       0.0979       NaN       0.9410       NaN
# 1352   Ocean Waves For Sleep       0.0797       NaN       0.9320       NaN
# 1353        Sir Simon Rattle       0.0640       NaN       0.9740       NaN
# ...

# %%
data_compilation.groupby("artist")[["danceability", "acousticness", "speechiness"]].agg({
    "danceability": ["mean", "std"],
    "acousticness": ["mean", "std"],
    "speechiness": ["mean", "std"]
}).sort_values(by=("danceability", "mean"), ascending=False).reset_index()
# Out:
#                            artist danceability           acousticness  \
#                                           mean       std         mean
# 0                       Nate Dogg     0.945000       NaN     0.087200
# 1                        Ice Cube     0.934000       NaN     0.031000
# 2                          Shaggy     0.929000       NaN     0.166000
# 3                     Ronnie Flex     0.900667  0.055012     0.132667
# 4                          Twista     0.900000       NaN     0.430000
# ..                            ...          ...       ...          ...
# 446  Royal Philharmonic Orchestra     0.141000       NaN     0.988000
# 447                Franz Schubert     0.105000       NaN     0.948000
# 448       Berliner Philharmoniker     0.076900       NaN     0.922000
# 449         Johann Sebastian Bach     0.076900       NaN     0.922000
# 450           Herbert von Karajan     0.076900       NaN     0.922000
#
#               speechiness
# ...

# %% [markdown]
# - Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, queremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:

# %% [markdown]
#         - Agrupa por artista y calcular la media de visitas y de likes.

# %%
data_youtube.groupby("artist")[["views" ,"likes"]].mean().reset_index()
# Out:
#                    artist         views         likes
# 0                     112  1.421284e+07  1.147985e+05
# 1                2 Chainz  2.628831e+08  1.983586e+06
# 2                    2Pac  2.235576e+08  1.617378e+06
# 3            3 Doors Down  4.051550e+07  1.776690e+05
# 4    A Tribe Called Quest  4.116738e+07  4.140350e+05
# ..                    ...           ...           ...
# 446               Zendaya  3.915290e+05  4.316000e+03
# 447                  Zion  3.948788e+08  1.232482e+06
# 448           back number  2.085921e+07  1.015970e+05
# 449                  fun.  6.697180e+05  4.173000e+03
# 450             will.i.am  2.663398e+07  1.346317e+05
#
# [451 rows x 3 columns]

# %% [markdown]
#         - Quedate con los 10 artistas que más visitas han tenido.

# %%
data_youtube.groupby("artist")["views"].mean().sort_values(ascending=False).reset_index().head(10)
# Out:
#                artist         views
# 0             Shakira  3.463816e+09
# 1      Ellie Goulding  2.283748e+09
# 2                 PSY  1.539136e+09
# 3              Europe  1.083818e+09
# 4            Bon Jovi  9.066678e+08
# 5         Neha Kakkar  8.821301e+08
# 6             Mithoon  8.658623e+08
# 7            Jessie J  7.172063e+08
# 8        Prince Royce  7.058518e+08
# 9  Earth, Wind & Fire  6.414077e+08

# %% [markdown]
#         - Quedate con los 10 artistas que más likes han tenido.

# %%
data_youtube.groupby("artist")["likes"].mean().sort_values(ascending=False).reset_index().head(10)
# Out:
#                artist       likes
# 0             Shakira  20327883.0
# 1      Ellie Goulding  12418131.0
# 2                 PSY   8084738.0
# 3              Europe   5666051.0
# 4  Earth, Wind & Fire   4804872.0
# 5            Jessie J   4573215.0
# 6             Mithoon   4562635.0
# 7        Prince Royce   3560430.5
# 8            Bon Jovi   3364863.0
# 9           Green Day   3300719.0

# %% [markdown]
# - BONUS Haced lo mismo para los datos de tipo "single".

# %% [markdown]
#         - Agrupa por artista y calcular la media de visitas y de likes.

# %%
data_youtube.groupby("track")[["views","likes"]].mean().reset_index()
# Out:
#                                                  track        views      likes
# 0                              (don't fear) the reaper   59838390.0   537094.0
# 1                             (what a) wonderful world   22465233.0   194774.0
# 2    (when you gonna) give it up to me (feat. keysh...  306887054.0  1317175.0
# 3                           (you are) my special angel    4089581.0    29891.0
# 4                                                  069    3785191.0    49617.0
# ..                                                 ...          ...        ...
# 683                                          zara zara    6996631.0    67027.0
# 684                                   zara zara - lofi     108272.0     2748.0
# 685                             zara zara - lofi chill     238924.0     4700.0
# 686                                       zero to hero   43190273.0   179776.0
# 687                                         オールドファッション   20859214.0   101597.0
#
# [688 rows x 3 columns]

# %% [markdown]
#         - Quedate con los 10 artistas que más visitas han tenido.

# %%
data_youtube.groupby("track")["views"].mean().sort_values(ascending=False).reset_index().head(10)
# Out:
#                                                track         views
# 0  waka waka (this time for africa) [the official...  3.463816e+09
# 1                                love me like you do  2.283748e+09
# 2                                          gentleman  1.539136e+09
# 3                                the final countdown  1.083818e+09
# 4                                   careless whisper  9.785189e+08
# 5                         total eclipse of the heart  9.368534e+08
# 6                                             always  9.066678e+08
# 7                                        sensualidad  8.971488e+08
# 8                           phir bhi tumko chaahunga  8.658625e+08
# 9                    last christmas - single version  7.758967e+08

# %% [markdown]
#         - Quedate con los 10 artistas que más likes han tenido.

# %%
data_youtube.groupby("track")["likes"].mean().sort_values(ascending=False).reset_index().head(10)
# Out:
#                                                track         likes
# 0  waka waka (this time for africa) [the official...  2.032788e+07
# 1                                love me like you do  1.241813e+07
# 2                                          gentleman  8.084738e+06
# 3                                   careless whisper  6.693888e+06
# 4                    sweet dreams (are made of this)  6.430703e+06
# 5                         boulevard of broken dreams  5.750425e+06
# 6                                the final countdown  5.666051e+06
# 7                                          september  4.804872e+06
# 8                                            fantasy  4.804872e+06
# 9     flashlight - from "pitch perfect 2" soundtrack  4.573215e+06
